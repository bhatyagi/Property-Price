# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\HP\OneDrive\Desktop\Property_Price.csv")
df
# Out:
#         Id  Building_Class Zoning_Class  Lot_Extent  Lot_Size Road_Type  \
# 0        1              60          RLD        65.0      8450     Paved
# 1        2              20          RLD        80.0      9600     Paved
# 2        3              60          RLD        68.0     11250     Paved
# 3        4              70          RLD        60.0      9550     Paved
# 4        5              60          RLD        84.0     14260     Paved
# ...    ...             ...          ...         ...       ...       ...
# 1454  1455              20          FVR        62.0      7500     Paved
# 1455  1456              60          RLD        62.0      7917     Paved
# 1456  1457              20          RLD        85.0     13175     Paved
# 1457  1458              70          RLD        66.0      9042     Paved
# 1458  1459              20          RLD        68.0      9717     Paved
#
#      Lane_Type Property_Shape Land_Outline Utility_Type  ... Pool_Area  \
# ...

# %%
df.shape
# Out:
# (1459, 81)

# %%
df.columns
# Out:
# Index(['Id', 'Building_Class', 'Zoning_Class', 'Lot_Extent', 'Lot_Size',
#        'Road_Type', 'Lane_Type', 'Property_Shape', 'Land_Outline',
#        'Utility_Type', 'Lot_Configuration', 'Property_Slope', 'Neighborhood',
#        'Condition1', 'Condition2', 'House_Type', 'House_Design',
#        'Overall_Material', 'House_Condition', 'Construction_Year',
#        'Remodel_Year', 'Roof_Design', 'Roof_Quality', 'Exterior1st',
#        'Exterior2nd', 'Brick_Veneer_Type', 'Brick_Veneer_Area',
#        'Exterior_Material', 'Exterior_Condition', 'Foundation_Type',
#        'Basement_Height', 'Basement_Condition', 'Exposure_Level',
#        'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF',
#        'Total_Basement_Area', 'Heating_Type', 'Heating_Quality',
#        'Air_Conditioning', 'Electrical_System', 'First_Floor_Area',
#        'Second_Floor_Area', 'LowQualFinSF', 'Grade_Living_Area',
#        'Underground_Full_Bathroom', 'Underground_Half_Bathroom',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 81 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Id                         1459 non-null   int64
#  1   Building_Class             1459 non-null   int64
#  2   Zoning_Class               1459 non-null   object
#  3   Lot_Extent                 1200 non-null   float64
#  4   Lot_Size                   1459 non-null   int64
#  5   Road_Type                  1459 non-null   object
#  6   Lane_Type                  91 non-null     object
#  7   Property_Shape             1459 non-null   object
#  8   Land_Outline               1459 non-null   object
#  9   Utility_Type               1459 non-null   object
#  10  Lot_Configuration          1459 non-null   object
#  11  Property_Slope             1459 non-null   object
#  12  Neighborhood               1459 non-null   object
# ...

# %%
df.describe()
# Out:
#                 Id  Building_Class   Lot_Extent       Lot_Size  \
# count  1459.000000     1459.000000  1200.000000    1459.000000
# mean    730.000000       56.922550    70.045833   10517.225497
# std     421.321334       42.304033    24.294456    9984.675721
# min       1.000000       20.000000    21.000000    1300.000000
# 25%     365.500000       20.000000    59.000000    7549.000000
# 50%     730.000000       50.000000    69.000000    9477.000000
# 75%    1094.500000       70.000000    80.000000   11603.000000
# max    1459.000000      190.000000   313.000000  215245.000000
#
#        Overall_Material  House_Condition  Construction_Year  Remodel_Year  \
# count       1459.000000      1459.000000        1459.000000   1459.000000
# mean           6.100069         5.575051        1971.272104   1984.879369
# std            1.383171         1.113125          30.212814     20.645927
# min            1.000000         1.000000        1872.000000   1950.000000
# ...

# %%
df.dtypes
# Out:
# Id                  int64
# Building_Class      int64
# Zoning_Class       object
# Lot_Extent        float64
# Lot_Size            int64
#                    ...
# Month_Sold          int64
# Year_Sold           int64
# Sale_Type          object
# Sale_Condition     object
# Sale_Price          int64
# Length: 81, dtype: object

# %%
df.nunique()
# Out:
# Id                1459
# Building_Class      15
# Zoning_Class         5
# Lot_Extent         110
# Lot_Size          1073
#                   ...
# Month_Sold          12
# Year_Sold            5
# Sale_Type            9
# Sale_Condition       6
# Sale_Price         662
# Length: 81, dtype: int64

# %%
df.isnull()
# Out:
#          Id  Building_Class  Zoning_Class  Lot_Extent  Lot_Size  Road_Type  \
# 0     False           False         False       False     False      False
# 1     False           False         False       False     False      False
# 2     False           False         False       False     False      False
# 3     False           False         False       False     False      False
# 4     False           False         False       False     False      False
# ...     ...             ...           ...         ...       ...        ...
# 1454  False           False         False       False     False      False
# 1455  False           False         False       False     False      False
# 1456  False           False         False       False     False      False
# 1457  False           False         False       False     False      False
# 1458  False           False         False       False     False      False
#
# ...

# %%
df.isnull().sum()
# Out:
# Id                  0
# Building_Class      0
# Zoning_Class        0
# Lot_Extent        259
# Lot_Size            0
#                  ...
# Month_Sold          0
# Year_Sold           0
# Sale_Type           0
# Sale_Condition      0
# Sale_Price          0
# Length: 81, dtype: int64

# %%
df.head(10)
# Out:
#    Id  Building_Class Zoning_Class  Lot_Extent  Lot_Size Road_Type Lane_Type  \
# 0   1              60          RLD        65.0      8450     Paved       NaN
# 1   2              20          RLD        80.0      9600     Paved       NaN
# 2   3              60          RLD        68.0     11250     Paved       NaN
# 3   4              70          RLD        60.0      9550     Paved       NaN
# 4   5              60          RLD        84.0     14260     Paved       NaN
# 5   6              50          RLD        85.0     14115     Paved       NaN
# 6   7              20          RLD        75.0     10084     Paved       NaN
# 7   8              60          RLD         NaN     10382     Paved       NaN
# 8   9              50          RMD        51.0      6120     Paved       NaN
# 9  10             190          RLD        50.0      7420     Paved       NaN
#
#   Property_Shape Land_Outline Utility_Type  ... Pool_Area Pool_Quality  \
# ...

# %%
df.tail(10)
# Out:
#         Id  Building_Class Zoning_Class  Lot_Extent  Lot_Size Road_Type  \
# 1449  1450             180          RMD        21.0      1533     Paved
# 1450  1451              90          RLD        60.0      9000     Paved
# 1451  1452              20          RLD        78.0      9262     Paved
# 1452  1453             180          RMD        35.0      3675     Paved
# 1453  1454              20          RLD        90.0     17217     Paved
# 1454  1455              20          FVR        62.0      7500     Paved
# 1455  1456              60          RLD        62.0      7917     Paved
# 1456  1457              20          RLD        85.0     13175     Paved
# 1457  1458              70          RLD        66.0      9042     Paved
# 1458  1459              20          RLD        68.0      9717     Paved
#
#      Lane_Type Property_Shape Land_Outline Utility_Type  ... Pool_Area  \
# 1449       NaN            Reg          Lvl       AllPub  ...         0
# ...

# %%
num=df.select_dtypes(include=np.number).columns
num
# Out:
# Index(['Id', 'Building_Class', 'Lot_Extent', 'Lot_Size', 'Overall_Material',
#        'House_Condition', 'Construction_Year', 'Remodel_Year',
#        'Brick_Veneer_Area', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'Total_Basement_Area', 'First_Floor_Area', 'Second_Floor_Area',
#        'LowQualFinSF', 'Grade_Living_Area', 'Underground_Full_Bathroom',
#        'Underground_Half_Bathroom', 'Full_Bathroom_Above_Grade',
#        'Half_Bathroom_Above_Grade', 'Bedroom_Above_Grade',
#        'Kitchen_Above_Grade', 'Rooms_Above_Grade', 'Fireplaces',
#        'Garage_Built_Year', 'Garage_Size', 'Garage_Area', 'W_Deck_Area',
#        'Open_Lobby_Area', 'Enclosed_Lobby_Area', 'Three_Season_Lobby_Area',
#        'Screen_Lobby_Area', 'Pool_Area', 'Miscellaneous_Value', 'Month_Sold',
#        'Year_Sold', 'Sale_Price'],
#       dtype='object')

# %%
cat=df.select_dtypes(include="object").columns
cat
# Out:
# Index(['Zoning_Class', 'Road_Type', 'Lane_Type', 'Property_Shape',
#        'Land_Outline', 'Utility_Type', 'Lot_Configuration', 'Property_Slope',
#        'Neighborhood', 'Condition1', 'Condition2', 'House_Type',
#        'House_Design', 'Roof_Design', 'Roof_Quality', 'Exterior1st',
#        'Exterior2nd', 'Brick_Veneer_Type', 'Exterior_Material',
#        'Exterior_Condition', 'Foundation_Type', 'Basement_Height',
#        'Basement_Condition', 'Exposure_Level', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating_Type', 'Heating_Quality', 'Air_Conditioning',
#        'Electrical_System', 'Kitchen_Quality', 'Functional_Rate',
#        'Fireplace_Quality', 'Garage', 'Garage_Finish_Year', 'Garage_Quality',
#        'Garage_Condition', 'Pavedd_Drive', 'Pool_Quality', 'Fence_Quality',
#        'Miscellaneous_Feature', 'Sale_Type', 'Sale_Condition'],
#       dtype='object')

# %%
df.mode()
# Out:
#         Id  Building_Class Zoning_Class  Lot_Extent  Lot_Size Road_Type  \
# 0        1            20.0          RLD        60.0    7200.0     Paved
# 1        2             NaN          NaN         NaN       NaN       NaN
# 2        3             NaN          NaN         NaN       NaN       NaN
# 3        4             NaN          NaN         NaN       NaN       NaN
# 4        5             NaN          NaN         NaN       NaN       NaN
# ...    ...             ...          ...         ...       ...       ...
# 1454  1455             NaN          NaN         NaN       NaN       NaN
# 1455  1456             NaN          NaN         NaN       NaN       NaN
# 1456  1457             NaN          NaN         NaN       NaN       NaN
# 1457  1458             NaN          NaN         NaN       NaN       NaN
# 1458  1459             NaN          NaN         NaN       NaN       NaN
#
#      Lane_Type Property_Shape Land_Outline Utility_Type  ... Pool_Area  \
# ...

# %%
df[cat].mode()
# Out:
#   Zoning_Class Road_Type Lane_Type Property_Shape Land_Outline Utility_Type  \
# 0          RLD     Paved      Grvl            Reg          Lvl       AllPub
#
#   Lot_Configuration Property_Slope Neighborhood Condition1  ...  Garage  \
# 0                 I             GS        NAmes       Norm  ...  Attchd
#
#   Garage_Finish_Year Garage_Quality Garage_Condition Pavedd_Drive  \
# 0                Unf             TA               TA            Y
#
#   Pool_Quality Fence_Quality Miscellaneous_Feature Sale_Type Sale_Condition
# 0           Gd         MnPrv                  Shed        WD         Normal
#
# [1 rows x 43 columns]

# %%
df[num].skew()
# Out:
# Id                            0.000000
# Building_Class                1.406938
# Lot_Extent                    2.163286
# Lot_Size                     12.203438
# Overall_Material              0.215719
# House_Condition               0.693682
# Construction_Year            -0.613700
# Remodel_Year                 -0.505239
# Brick_Veneer_Area             2.668016
# BsmtFinSF1                    1.687498
# BsmtFinSF2                    4.264538
# BsmtUnfSF                     0.919485
# Total_Basement_Area           1.524923
# First_Floor_Area              1.376856
# Second_Floor_Area             0.811989
# LowQualFinSF                  9.008149
# Grade_Living_Area             1.365502
# Underground_Full_Bathroom     0.597963
# Underground_Half_Bathroom     4.101759
# Full_Bathroom_Above_Grade     0.035218
# Half_Bathroom_Above_Grade     0.677972
# Bedroom_Above_Grade           0.212058
# Kitchen_Above_Grade           4.486640
# Rooms_Above_Grade             0.675547
# ...

# %%
df[num].median()
# Out:
# Id                              730.000000
# Building_Class                   50.000000
# Lot_Extent                       69.000000
# Lot_Size                       9477.000000
# Overall_Material                  6.000000
# House_Condition                   5.000000
# Construction_Year              1973.000000
# Remodel_Year                   1994.000000
# Brick_Veneer_Area                 0.000000
# BsmtFinSF1                      383.000000
# BsmtFinSF2                        0.000000
# BsmtUnfSF                       479.000000
# Total_Basement_Area             991.000000
# First_Floor_Area               1086.000000
# Second_Floor_Area                 0.000000
# LowQualFinSF                      0.000000
# Grade_Living_Area              1464.000000
# Underground_Full_Bathroom         0.000000
# Underground_Half_Bathroom         0.000000
# Full_Bathroom_Above_Grade         2.000000
# Half_Bathroom_Above_Grade         0.000000
# Bedroom_Above_Grade               3.000000
# ...

# %%
df[num].mean()
# Out:
# Id                              730.000000
# Building_Class                   56.922550
# Lot_Extent                       70.045833
# Lot_Size                      10517.225497
# Overall_Material                  6.100069
# House_Condition                   5.575051
# Construction_Year              1971.272104
# Remodel_Year                   1984.879369
# Brick_Veneer_Area               103.756720
# BsmtFinSF1                      443.374914
# BsmtFinSF2                       46.382454
# BsmtUnfSF                       567.535984
# Total_Basement_Area            1057.293352
# First_Floor_Area               1162.562714
# Second_Floor_Area               347.230295
# LowQualFinSF                      5.848526
# Grade_Living_Area              1515.641535
# Underground_Full_Bathroom         0.424949
# Underground_Half_Bathroom         0.057574
# Full_Bathroom_Above_Grade         1.565456
# Half_Bathroom_Above_Grade         0.382454
# Bedroom_Above_Grade               2.866347
# ...

# %%
df[num].cov()
# Out:
#                                       Id  Building_Class     Lot_Extent  \
# Id                         177511.666667      217.578875    -111.509147
# Building_Class                217.578875     1789.631172    -404.622689
# Lot_Extent                   -111.509147     -404.622689     590.220583
# Lot_Size                  -139625.253772   -59072.580603   82066.587910
# Overall_Material              -16.000000        1.882241       8.684918
# House_Condition                 5.707133       -2.783278      -1.577057
# Construction_Year            -158.854595       35.447015      95.210863
# Remodel_Year                 -181.659122       34.961158      45.866250
# Brick_Veneer_Area           -3793.089215      173.315171     872.365898
# BsmtFinSF1                  -1160.209877    -1338.495634    2636.486228
# BsmtFinSF2                   -528.054870     -442.121250     186.350834
# BsmtUnfSF                   -1264.229767    -2643.692341    1448.437212
# ...

# %%
df[num].kurt()
# Out:
# Id                            -1.200000
# Building_Class                 1.578066
# Lot_Extent                    17.438785
# Lot_Size                     203.101490
# Overall_Material               0.096112
# House_Condition                1.105136
# Construction_Year             -0.440808
# Remodel_Year                  -1.270487
# Brick_Veneer_Area             10.075050
# BsmtFinSF1                    11.126068
# BsmtFinSF2                    20.184015
# BsmtUnfSF                      0.474069
# Total_Basement_Area           13.245817
# First_Floor_Area               5.741475
# Second_Floor_Area             -0.555067
# LowQualFinSF                  83.174678
# Grade_Living_Area              4.890470
# Underground_Full_Bathroom     -0.836153
# Underground_Half_Bathroom     16.382219
# Full_Bathroom_Above_Grade     -0.856276
# Half_Bathroom_Above_Grade     -1.073539
# Bedroom_Above_Grade            2.227583
# Kitchen_Above_Grade           21.514545
# ...

# %%
df[num].corr()
# Out:
#                                  Id  Building_Class  Lot_Extent  Lot_Size  \
# Id                         1.000000        0.012207   -0.010911 -0.033191
# Building_Class             0.012207        1.000000   -0.386327 -0.139852
# Lot_Extent                -0.010911       -0.386327    1.000000  0.426103
# Lot_Size                  -0.033191       -0.139852    0.426103  1.000000
# Overall_Material          -0.027456        0.032168    0.251850  0.105797
# House_Condition            0.012169       -0.059106   -0.059286 -0.005621
# Construction_Year         -0.012479        0.027734    0.123383  0.014220
# Remodel_Year              -0.020884        0.040029    0.089063  0.013754
# Brick_Veneer_Area         -0.049671        0.022600    0.193581  0.104149
# BsmtFinSF1                -0.006037       -0.069364    0.233563  0.214190
# BsmtFinSF2                -0.007773       -0.064813    0.049682  0.111317
# BsmtUnfSF                 -0.006791       -0.141426    0.132874 -0.002658
# ...

# %%
df[num].std()
# Out:
# Id                             421.321334
# Building_Class                  42.304033
# Lot_Extent                      24.294456
# Lot_Size                      9984.675721
# Overall_Material                 1.383171
# House_Condition                  1.113125
# Construction_Year               30.212814
# Remodel_Year                    20.645927
# Brick_Veneer_Area              181.108150
# BsmtFinSF1                     456.142186
# BsmtFinSF2                     161.248500
# BsmtUnfSF                      441.874057
# Total_Basement_Area            438.824912
# First_Floor_Area               386.712553
# Second_Floor_Area              436.583480
# LowQualFinSF                    48.639512
# Grade_Living_Area              525.616607
# Underground_Full_Bathroom        0.518870
# Underground_Half_Bathroom        0.238830
# Full_Bathroom_Above_Grade        0.550906
# Half_Bathroom_Above_Grade        0.502798
# Bedroom_Above_Grade              0.816050
# ...

# %%
df['Zoning_Class'].unique()
# Out:
# array(['RLD', 'RMD', 'Commer', 'FVR', 'RHD'], dtype=object)

# %%
df['Zoning_Class'].nunique()
# Out:
# 5

# %%
df['Road_Type'].unique()
# Out:
# array(['Paved', 'Gravel'], dtype=object)

# %%
df['Road_Type'].nunique()
# Out:
# 2

# %%
df[cat].nunique()
# Out:
# Zoning_Class              5
# Road_Type                 2
# Lane_Type                 2
# Property_Shape            4
# Land_Outline              4
# Utility_Type              2
# Lot_Configuration         5
# Property_Slope            3
# Neighborhood             25
# Condition1                9
# Condition2                8
# House_Type                5
# House_Design              8
# Roof_Design               6
# Roof_Quality              8
# Exterior1st              15
# Exterior2nd              16
# Brick_Veneer_Type         3
# Exterior_Material         4
# Exterior_Condition        5
# Foundation_Type           6
# Basement_Height           4
# Basement_Condition        4
# Exposure_Level            4
# BsmtFinType1              6
# BsmtFinType2              6
# Heating_Type              6
# Heating_Quality           5
# Air_Conditioning          2
# Electrical_System         5
# Kitchen_Quality           4
# Functional_Rate           8
# Fireplace_Quality         5
# ...

# %%
sns.heatmap(df[num].corr(),annot=True)
plt.show()

# %%
sns.countplot(y='Zoning_Class',data=df)
# Out:
# <Axes: xlabel='count', ylabel='Zoning_Class'>

# %%
sns.boxplot(x='Id',y='Zoning_Class',data=df)
# Out:
# <Axes: xlabel='Id', ylabel='Zoning_Class'>

# %%
sns.scatterplot(x='Lot_Extent',y='Overall_Material',data=df)
# Out:
# <Axes: xlabel='Lot_Extent', ylabel='Overall_Material'>

# %%
sns.histplot(x='Garage_Size',data=df)
# Out:
# <Axes: xlabel='Garage_Size', ylabel='Count'>

# %%
sns.histplot(x="Garage_Size",y='Fireplaces',data=df)
# Out:
# <Axes: xlabel='Garage_Size', ylabel='Fireplaces'>

# %%
sns.displot(df['Year_Sold'])
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.barplot(x='Id',y='Utility_Type',data=df)
# Out:
# <Axes: xlabel='Id', ylabel='Utility_Type'>

# %%
sns.scatterplot(x='Brick_Veneer_Area',y='BsmtFinSF1',data=df)
# Out:
# <Axes: xlabel='Brick_Veneer_Area', ylabel='BsmtFinSF1'>

# %%
plt.figure(figsize=(15,10))
t=1
for i in num:
    plt.subplot(13,3,t)
    sns.scatterplot(df.loc[:,i])
    plt.title(i)
    t=t+1
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,10))
m=1
for i in num:
    plt.subplot(13,3,m)
    sns.countplot(df.loc[:,i])
    plt.title(i)
    m=m+1
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,10))
z=1
for i in num:
    plt.subplot(13,3,z)
    sns.histplot(df.loc[:,i])
    plt.title(i)
    z=z+1
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25236\3881730823.py:8: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
plt.figure(figsize=(15,10))
n=1
for i in cat:
    plt.subplot(11,4,n)
    sns.histplot(df.loc[:,i])
    plt.title(i)
    n=n+1
plt.tight_layout()
plt.show()

# %%
sns.boxplot(x='Lot_Extent',y='Id',data=df)
# Out:
# <Axes: xlabel='Lot_Extent', ylabel='Id'>

# %%
sns.lineplot(x='Id',y='Lot_Size',data=df)
# Out:
# <Axes: xlabel='Id', ylabel='Lot_Size'>

# %%
sns.lineplot(x='Road_Type',y='Lane_Type',data=df)
# Out:
# <Axes: xlabel='Road_Type', ylabel='Lane_Type'>

# %%
df['Pool_Area'].nunique()
# Out:
# 8

# %%
df['Pool_Area'].unique()
# Out:
# array([  0, 512, 648, 576, 555, 480, 519, 738], dtype=int64)

# %%
df[num].nunique()
# Out:
# Id                           1459
# Building_Class                 15
# Lot_Extent                    110
# Lot_Size                     1073
# Overall_Material               10
# House_Condition                 9
# Construction_Year             112
# Remodel_Year                   61
# Brick_Veneer_Area             327
# BsmtFinSF1                    636
# BsmtFinSF2                    144
# BsmtUnfSF                     779
# Total_Basement_Area           721
# First_Floor_Area              752
# Second_Floor_Area             417
# LowQualFinSF                   24
# Grade_Living_Area             860
# Underground_Full_Bathroom       4
# Underground_Half_Bathroom       3
# Full_Bathroom_Above_Grade       4
# Half_Bathroom_Above_Grade       3
# Bedroom_Above_Grade             8
# Kitchen_Above_Grade             4
# Rooms_Above_Grade              12
# Fireplaces                      4
# Garage_Built_Year              97
# Garage_Size                     5
# ...

# %%
df[cat].nunique()
# Out:
# Zoning_Class              5
# Road_Type                 2
# Lane_Type                 2
# Property_Shape            4
# Land_Outline              4
# Utility_Type              2
# Lot_Configuration         5
# Property_Slope            3
# Neighborhood             25
# Condition1                9
# Condition2                8
# House_Type                5
# House_Design              8
# Roof_Design               6
# Roof_Quality              8
# Exterior1st              15
# Exterior2nd              16
# Brick_Veneer_Type         3
# Exterior_Material         4
# Exterior_Condition        5
# Foundation_Type           6
# Basement_Height           4
# Basement_Condition        4
# Exposure_Level            4
# BsmtFinType1              6
# BsmtFinType2              6
# Heating_Type              6
# Heating_Quality           5
# Air_Conditioning          2
# Electrical_System         5
# Kitchen_Quality           4
# Functional_Rate           8
# Fireplace_Quality         5
# ...

# %%
df.drop('Air_Conditioning',axis=1)
# Out:
#         Id  Building_Class Zoning_Class  Lot_Extent  Lot_Size Road_Type  \
# 0        1              60          RLD        65.0      8450     Paved
# 1        2              20          RLD        80.0      9600     Paved
# 2        3              60          RLD        68.0     11250     Paved
# 3        4              70          RLD        60.0      9550     Paved
# 4        5              60          RLD        84.0     14260     Paved
# ...    ...             ...          ...         ...       ...       ...
# 1454  1455              20          FVR        62.0      7500     Paved
# 1455  1456              60          RLD        62.0      7917     Paved
# 1456  1457              20          RLD        85.0     13175     Paved
# 1457  1458              70          RLD        66.0      9042     Paved
# 1458  1459              20          RLD        68.0      9717     Paved
#
#      Lane_Type Property_Shape Land_Outline Utility_Type  ... Pool_Area  \
# ...

# %%
df.drop('Pool_Area',axis=1)
# Out:
#         Id  Building_Class Zoning_Class  Lot_Extent  Lot_Size Road_Type  \
# 0        1              60          RLD        65.0      8450     Paved
# 1        2              20          RLD        80.0      9600     Paved
# 2        3              60          RLD        68.0     11250     Paved
# 3        4              70          RLD        60.0      9550     Paved
# 4        5              60          RLD        84.0     14260     Paved
# ...    ...             ...          ...         ...       ...       ...
# 1454  1455              20          FVR        62.0      7500     Paved
# 1455  1456              60          RLD        62.0      7917     Paved
# 1456  1457              20          RLD        85.0     13175     Paved
# 1457  1458              70          RLD        66.0      9042     Paved
# 1458  1459              20          RLD        68.0      9717     Paved
#
#      Lane_Type Property_Shape Land_Outline Utility_Type  ...  \
# ...

# %%
df=pd.read_csv(r"C:\Users\HP\OneDrive\Desktop\Property_Price.csv")
df
# Out:
#         Id  Building_Class Zoning_Class  Lot_Extent  Lot_Size Road_Type  \
# 0        1              60          RLD        65.0      8450     Paved
# 1        2              20          RLD        80.0      9600     Paved
# 2        3              60          RLD        68.0     11250     Paved
# 3        4              70          RLD        60.0      9550     Paved
# 4        5              60          RLD        84.0     14260     Paved
# ...    ...             ...          ...         ...       ...       ...
# 1454  1455              20          FVR        62.0      7500     Paved
# 1455  1456              60          RLD        62.0      7917     Paved
# 1456  1457              20          RLD        85.0     13175     Paved
# 1457  1458              70          RLD        66.0      9042     Paved
# 1458  1459              20          RLD        68.0      9717     Paved
#
#      Lane_Type Property_Shape Land_Outline Utility_Type  ... Pool_Area  \
# ...

# %%
d=df.dropna
d
# Out:
# <bound method DataFrame.dropna of         Id  Building_Class Zoning_Class  Lot_Extent  Lot_Size Road_Type  \
# 0        1              60          RLD        65.0      8450     Paved
# 1        2              20          RLD        80.0      9600     Paved
# 2        3              60          RLD        68.0     11250     Paved
# 3        4              70          RLD        60.0      9550     Paved
# 4        5              60          RLD        84.0     14260     Paved
# ...    ...             ...          ...         ...       ...       ...
# 1454  1455              20          FVR        62.0      7500     Paved
# 1455  1456              60          RLD        62.0      7917     Paved
# 1456  1457              20          RLD        85.0     13175     Paved
# 1457  1458              70          RLD        66.0      9042     Paved
# 1458  1459              20          RLD        68.0      9717     Paved
#
# ...

# %%
d=df.dropna(how='all')
d
# Out:
#         Id  Building_Class Zoning_Class  Lot_Extent  Lot_Size Road_Type  \
# 0        1              60          RLD        65.0      8450     Paved
# 1        2              20          RLD        80.0      9600     Paved
# 2        3              60          RLD        68.0     11250     Paved
# 3        4              70          RLD        60.0      9550     Paved
# 4        5              60          RLD        84.0     14260     Paved
# ...    ...             ...          ...         ...       ...       ...
# 1454  1455              20          FVR        62.0      7500     Paved
# 1455  1456              60          RLD        62.0      7917     Paved
# 1456  1457              20          RLD        85.0     13175     Paved
# 1457  1458              70          RLD        66.0      9042     Paved
# 1458  1459              20          RLD        68.0      9717     Paved
#
#      Lane_Type Property_Shape Land_Outline Utility_Type  ... Pool_Area  \
# ...

# %%
d=df.dropna(subset="Lane_Type")
d
# Out:
#         Id  Building_Class Zoning_Class  Lot_Extent  Lot_Size Road_Type  \
# 21      22              45          RMD        57.0      7449     Paved
# 30      31              70       Commer        50.0      8500     Paved
# 56      57             160          FVR        24.0      2645     Paved
# 79      80              50          RMD        60.0     10440     Paved
# 87      88             160          FVR        40.0      3951     Paved
# ...    ...             ...          ...         ...       ...       ...
# 1404  1405              50          RLD        60.0     10410     Paved
# 1414  1415              50          RLD        64.0     13053     Paved
# 1427  1428              50          RLD        60.0     10930     Paved
# 1432  1433              30          RLD        60.0     10800     Paved
# 1454  1455              20          FVR        62.0      7500     Paved
#
#      Lane_Type Property_Shape Land_Outline Utility_Type  ... Pool_Area  \
# ...

# %%
d=df.dropna(axis=1,how='all')
d
# Out:
#         Id  Building_Class Zoning_Class  Lot_Extent  Lot_Size Road_Type  \
# 0        1              60          RLD        65.0      8450     Paved
# 1        2              20          RLD        80.0      9600     Paved
# 2        3              60          RLD        68.0     11250     Paved
# 3        4              70          RLD        60.0      9550     Paved
# 4        5              60          RLD        84.0     14260     Paved
# ...    ...             ...          ...         ...       ...       ...
# 1454  1455              20          FVR        62.0      7500     Paved
# 1455  1456              60          RLD        62.0      7917     Paved
# 1456  1457              20          RLD        85.0     13175     Paved
# 1457  1458              70          RLD        66.0      9042     Paved
# 1458  1459              20          RLD        68.0      9717     Paved
#
#      Lane_Type Property_Shape Land_Outline Utility_Type  ... Pool_Area  \
# ...

# %%
df['Pool_Area'].fillna(df['Pool_Area'].mean(),inplace=True)

# %%
df['Pool_Area'].fillna(1)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1454    0
# 1455    0
# 1456    0
# 1457    0
# 1458    0
# Name: Pool_Area, Length: 1459, dtype: int64

# %%
df.head()
# Out:
#    Id  Building_Class Zoning_Class  Lot_Extent  Lot_Size Road_Type Lane_Type  \
# 0   1              60          RLD        65.0      8450     Paved       NaN
# 1   2              20          RLD        80.0      9600     Paved       NaN
# 2   3              60          RLD        68.0     11250     Paved       NaN
# 3   4              70          RLD        60.0      9550     Paved       NaN
# 4   5              60          RLD        84.0     14260     Paved       NaN
#
#   Property_Shape Land_Outline Utility_Type  ... Pool_Area Pool_Quality  \
# 0            Reg          Lvl       AllPub  ...         0          NaN
# 1            Reg          Lvl       AllPub  ...         0          NaN
# 2            IR1          Lvl       AllPub  ...         0          NaN
# 3            IR1          Lvl       AllPub  ...         0          NaN
# 4            IR1          Lvl       AllPub  ...         0          NaN
#
#   Fence_Quality Miscellaneous_Feature Miscellaneous_Value Month_Sold  \
# ...

# %%
df.isnull().sum()
# Out:
# Id                  0
# Building_Class      0
# Zoning_Class        0
# Lot_Extent        259
# Lot_Size            0
#                  ...
# Month_Sold          0
# Year_Sold           0
# Sale_Type           0
# Sale_Condition      0
# Sale_Price          0
# Length: 81, dtype: int64

# %%
df['Lane_Type'].fillna(df['Lane_Type'].mode,inplace=True)

# %%
df.isnull()
# Out:
#          Id  Building_Class  Zoning_Class  Lot_Extent  Lot_Size  Road_Type  \
# 0     False           False         False       False     False      False
# 1     False           False         False       False     False      False
# 2     False           False         False       False     False      False
# 3     False           False         False       False     False      False
# 4     False           False         False       False     False      False
# ...     ...             ...           ...         ...       ...        ...
# 1454  False           False         False       False     False      False
# 1455  False           False         False       False     False      False
# 1456  False           False         False       False     False      False
# 1457  False           False         False       False     False      False
# 1458  False           False         False       False     False      False
#
# ...

# %%
df.isnull().sum()
# Out:
# Id                  0
# Building_Class      0
# Zoning_Class        0
# Lot_Extent        259
# Lot_Size            0
#                  ...
# Month_Sold          0
# Year_Sold           0
# Sale_Type           0
# Sale_Condition      0
# Sale_Price          0
# Length: 81, dtype: int64

# %%
df['Lot_Extent'].fillna(df['Lot_Extent'].median,inplace=True)

# %%
df.isnull().sum()
# Out:
# Id                0
# Building_Class    0
# Zoning_Class      0
# Lot_Extent        0
# Lot_Size          0
#                  ..
# Month_Sold        0
# Year_Sold         0
# Sale_Type         0
# Sale_Condition    0
# Sale_Price        0
# Length: 81, dtype: int64

# %%
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 81 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Id                         1459 non-null   int64
#  1   Building_Class             1459 non-null   int64
#  2   Zoning_Class               1459 non-null   object
#  3   Lot_Extent                 1459 non-null   object
#  4   Lot_Size                   1459 non-null   int64
#  5   Road_Type                  1459 non-null   object
#  6   Lane_Type                  1459 non-null   object
#  7   Property_Shape             1459 non-null   object
#  8   Land_Outline               1459 non-null   object
#  9   Utility_Type               1459 non-null   object
#  10  Lot_Configuration          1459 non-null   object
#  11  Property_Slope             1459 non-null   object
#  12  Neighborhood               1459 non-null   object
# ...
